# %%
(###]Do you like using jupter notebooks?
The over all using experience of Jupter Notebooks is really user friendly. And the whole learning process is really easy.

# %%
(###)What do you want to learn more about in Jupyter Notebooks
 I want to learn more about what can i do more with Jupter Notebooks. For example. what can Jupyter Notebooks do to make my future career earier.

# %% [markdown]
# ![thumbnail_night star.jpg](data:image/jpeg;base64,...)
